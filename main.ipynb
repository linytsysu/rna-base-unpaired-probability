# %%
# !tree /home/aistudio/data
# Out:
# /home/aistudio/data
#
# 0 directories, 0 files

# %%
# !tree /home/aistudio/work -L 2
# Out:
# /home/aistudio/work
# ├── data
# │   ├── B_board_112_seqs.txt
# │   ├── dev.txt
# │   ├── test_nolabel.txt
# │   └── train.txt
# └── src
#     ├── const.py
#     ├── dataset.py
#     ├── __init__.py
#     ├── main.py
#     ├── network.py
#     ├── utils.py
#     └── vocabulary.py
#
# 2 directories, 11 files

# %%
# !cd work; python src/main.py train --model-path-base model --layers 4 --dmodel 32 --epochs 5
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# 2021-05-11 09:32:09.742993
# # python3 src/main.py train --model-path-base model --layers 4 --dmodel 32 --epochs 5
# # Training set contains 4750 Sequences.
# # Validation set contains 250 Sequences.
# # Paddle: Using device: CUDAPlace(0)
# # Initializing model...
# initializing vacabularies... done.
# ...

# %%
# !cd work; python src/main.py test --model-path-base model/model_dev\=0.0719 --layers 4 --dmodel 32
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# Loading data...
# Loading model...
# W0511 12:00:38.900941  5865 device_context.cc:362] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.0, Runtime API Version: 10.1
# W0511 12:00:38.907183  5865 device_context.cc:372] device: 0, cuDNN Version: 7.6.
# ...
